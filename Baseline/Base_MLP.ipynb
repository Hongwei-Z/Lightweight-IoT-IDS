# %%
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
folder_path = 'Processed_Datasets'
file_names = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

dataframes = []
for file_name in file_names:
    file_path = os.path.join(folder_path, file_name)
    df = pd.read_csv(file_path)
    dataframes.append(df)

combined_df = pd.concat(dataframes, ignore_index=True)
shuffled_df = shuffle(combined_df, random_state=42)

print(shuffled_df.shape)
# Out:
# (4000000, 40)

# %%
X = shuffled_df.drop('Label', axis=1)
y = shuffled_df['Label']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

mlp = MLPClassifier(hidden_layer_sizes=(64, 32), max_iter=1000)
mlp.fit(X_train, y_train)

y_pred = mlp.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# Test Accuracy: 0.7623

# %%
report = classification_report(y_test, y_pred)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.72      0.69    149446
#            1       0.71      0.70      0.70    149445
#            2       0.84      0.73      0.78    149955
#            3       0.76      0.86      0.81    150198
#            4       1.00      1.00      1.00    150675
#            5       0.65      0.61      0.63    150140
#            6       0.88      0.84      0.86    150029
#            7       0.60      0.63      0.62    150112
#
#     accuracy                           0.76   1200000
#    macro avg       0.76      0.76      0.76   1200000
# weighted avg       0.77      0.76      0.76   1200000
